# %%
from deck_class import Deck
from player_class import Player
from split_deck import split_deck
from highest_card import highest_card
from war import war


def war_card_game():

     # Create the deck of the game and shuffle it.
     mydeck =Deck()
     mydeck.shuffle_deck()

     # Take the number of playing, and their names.
     num_of_players = int(input('Enter the number of players: '))
     players =[]
     for i in range(num_of_players):
          name = input(f"Enter the name of player{i+1}: ")
          players.append(Player(name))

     # Split the deck evenly to all players.
     split_deck(mydeck,players)

     game_on = True
     i = 1 
     while game_on and i != 500: # A limit of 500 rounds is set!
          # For each round print number of cards each player has!
          print(f'\nRound {i}:')
          for player in players:
               print(f'{player.name} has {len(player.player_deck)} cards on his deck.')
          
          # Now each player draw a card from their deck.
          game_cards=[]
          k = 0
          while k < len(players):
               # Here it is checked if the player has cards left on his deck.
               # If not, he is removed from the game!
               if len(players[k].player_deck) == 0:
                    print(f'{players[k].name} is out of the game!')
                    players.pop(k)
               else:
                    game_cards.append(players[k].remove_card())
                    k+=1

          # Here we check if it's only one player in the game, then game over!
          if len(players) == 1:
               print("Game Over!")
               print(f'{players[0].name} is the winner!')
               break

          # To have an idea of cards drew by each player in this round!
          print('Cards in play this round are:')
          for card in game_cards:
               print(card)

          # Get positions of players with the highest card of the round
          winner_pos=highest_card(game_cards)
          print(winner_pos)
          
          # If there is only one player with the highest card,
          #  then he is the winner of this round.
          if len(winner_pos) == 1:
               print(f'{players[winner_pos[0]].name} is the winner of this round!')
               players[winner_pos[0]].win_card(game_cards)
          # If there are more than one player, then we have war.
          else:
               players = war(game_cards, winner_pos, players)
                    
          i += 1

war_card_game()
               
#CHECK Round 59!!!
# Out:
# Round 1:
# Xheku has 7 cards on his deck.
# Andi has 7 cards on his deck.
# Ildi has 7 cards on his deck.
# Xhoni has 7 cards on his deck.
# Keli has 7 cards on his deck.
# Brian has 7 cards on his deck.
# Klejdi has 7 cards on his deck.
# Cards in play this round are:
# Queen of Spades
# Five of Diamonds
# Nine of Hearts
# Two of Diamonds
# Five of Hearts
# Three of Hearts
# Ten of Spades
# [0]
# Xheku is the winner of this round!
#
# Round 2:
# Xheku has 13 cards on his deck.
# Andi has 6 cards on his deck.
# Ildi has 6 cards on his deck.
# Xhoni has 6 cards on his deck.
# Keli has 6 cards on his deck.
# Brian has 6 cards on his deck.
# Klejdi has 6 cards on his deck.
# Cards in play this round are:
# Three of Diamonds
# Three of Clubs
# Two of Spades
# Seven of Hearts
# Ten of Hearts
# Nine of Spades
# Jack of Diamonds
# [6]
# Klejdi is the winner of this round!
#
# Round 3:
# Xheku has 12 cards on his deck.
# Andi has 5 cards on his deck.
# Ildi has 5 cards on his deck.
# Xhoni has 5 cards on his deck.
# Keli has 5 cards on his deck.
# Brian has 5 cards on his deck.
# Klejdi has 12 cards on his deck.
# Cards in play this round are:
# Ten of Clubs
# Ace of Spades
# King of Clubs
# Six of Clubs
# Two of Hearts
# Eight of Diamonds
# Jack of Spades
# [1]
# Andi is the winner of this round!
#
# Round 4:
# Xheku has 11 cards on his deck.
# Andi has 11 cards on his deck.
# Ildi has 4 cards on his deck.
# Xhoni has 4 cards on his deck.
# Keli has 4 cards on his deck.
# Brian has 4 cards on his deck.
# Klejdi has 11 cards on his deck.
# Cards in play this round are:
# Jack of Hearts
# Jack of Clubs
# Six of Spades
# Ace of Clubs
# Seven of Spades
# Nine of Diamonds
# Queen of Clubs
# [3]
# Xhoni is the winner of this round!
#
# Round 5:
# Xheku has 10 cards on his deck.
# Andi has 10 cards on his deck.
# Ildi has 3 cards on his deck.
# Xhoni has 10 cards on his deck.
# Keli has 3 cards on his deck.
# Brian has 3 cards on his deck.
# Klejdi has 10 cards on his deck.
# Cards in play this round are:
# Seven of Clubs
# Queen of Hearts
# Three of Spades
# Four of Hearts
# Eight of Clubs
# Nine of Clubs
# Eight of Spades
# [1]
# Andi is the winner of this round!
#
# Round 6:
# Xheku has 9 cards on his deck.
# Andi has 16 cards on his deck.
# Ildi has 2 cards on his deck.
# Xhoni has 9 cards on his deck.
# Keli has 2 cards on his deck.
# Brian has 2 cards on his deck.
# Klejdi has 9 cards on his deck.
# Cards in play this round are:
# Four of Diamonds
# Eight of Hearts
# King of Spades
# Queen of Diamonds
# Ten of Diamonds
# Six of Hearts
# Five of Clubs
# [2]
# Ildi is the winner of this round!
#
# Round 7:
# Xheku has 8 cards on his deck.
# Andi has 15 cards on his deck.
# Ildi has 8 cards on his deck.
# Xhoni has 8 cards on his deck.
# Keli has 1 cards on his deck.
# Brian has 1 cards on his deck.
# Klejdi has 8 cards on his deck.
# Cards in play this round are:
# King of Hearts
# Four of Spades
# King of Diamonds
# Ace of Diamonds
# Two of Clubs
# Seven of Diamonds
# Five of Spades
# [3]
# Xhoni is the winner of this round!
#
# Round 8:
# Xheku has 7 cards on his deck.
# Andi has 14 cards on his deck.
# Ildi has 7 cards on his deck.
# Xhoni has 14 cards on his deck.
# Keli has 0 cards on his deck.
# Brian has 0 cards on his deck.
# Klejdi has 7 cards on his deck.
# Keli is out of the game!
# Brian is out of the game!
# Cards in play this round are:
# Ten of Spades
# Jack of Spades
# Five of Clubs
# Queen of Clubs
# Jack of Diamonds
# [3]
# Xhoni is the winner of this round!
#
# Round 9:
# Xheku has 6 cards on his deck.
# Andi has 13 cards on his deck.
# Ildi has 6 cards on his deck.
# Xhoni has 18 cards on his deck.
# Klejdi has 6 cards on his deck.
# Cards in play this round are:
# Three of Hearts
# Eight of Diamonds
# Six of Hearts
# Nine of Diamonds
# Nine of Spades
# [3, 4]
# Xhoni is the winner of this round!
#
# Round 10:
# Xheku has 5 cards on his deck.
# Andi has 12 cards on his deck.
# Ildi has 5 cards on his deck.
# Xhoni has 26 cards on his deck.
# Klejdi has 1 cards on his deck.
# Cards in play this round are:
# Five of Hearts
# Two of Hearts
# Ten of Diamonds
# Jack of Hearts
# Three of Diamonds
# [3]
# Xhoni is the winner of this round!
#
# Round 11:
# Xheku has 4 cards on his deck.
# Andi has 11 cards on his deck.
# Ildi has 4 cards on his deck.
# Xhoni has 30 cards on his deck.
# Klejdi has 0 cards on his deck.
# Klejdi is out of the game!
# Cards in play this round are:
# Two of Diamonds
# Six of Clubs
# Queen of Diamonds
# Five of Spades
# [2]
# Ildi is the winner of this round!
#
# Round 12:
# Xheku has 3 cards on his deck.
# Andi has 10 cards on his deck.
# Ildi has 7 cards on his deck.
# Xhoni has 29 cards on his deck.
# Cards in play this round are:
# Nine of Hearts
# King of Clubs
# King of Spades
# Seven of Diamonds
# [1, 2]
# Ildi is the winner of this round!
#
# Round 13:
# Xheku has 2 cards on his deck.
# Andi has 5 cards on his deck.
# Ildi has 14 cards on his deck.
# Xhoni has 28 cards on his deck.
# Cards in play this round are:
# Five of Diamonds
# Eight of Clubs
# Six of Clubs
# Two of Clubs
# [1]
# Andi is the winner of this round!
#
# Round 14:
# Xheku has 1 cards on his deck.
# Andi has 8 cards on his deck.
# Ildi has 13 cards on his deck.
# Xhoni has 27 cards on his deck.
# Cards in play this round are:
# Queen of Spades
# Four of Hearts
# Two of Diamonds
# Ace of Diamonds
# [3]
# Xhoni is the winner of this round!
#
# Round 15:
# Xheku has 0 cards on his deck.
# Andi has 7 cards on his deck.
# Ildi has 12 cards on his deck.
# Xhoni has 30 cards on his deck.
# Xheku is out of the game!
# Cards in play this round are:
# Three of Spades
# Queen of Diamonds
# King of Diamonds
# [2]
# Xhoni is the winner of this round!
#
# Round 16:
# Andi has 6 cards on his deck.
# Ildi has 11 cards on his deck.
# Xhoni has 32 cards on his deck.
# Cards in play this round are:
# Queen of Hearts
# Nine of Clubs
# Four of Spades
# [0]
# Andi is the winner of this round!
#
# Round 17:
# Andi has 8 cards on his deck.
# Ildi has 10 cards on his deck.
# Xhoni has 31 cards on his deck.
# Cards in play this round are:
# Seven of Clubs
# Five of Spades
# King of Hearts
# [2]
# Xhoni is the winner of this round!
#
# Round 18:
# Andi has 7 cards on his deck.
# Ildi has 9 cards on his deck.
# Xhoni has 33 cards on his deck.
# Cards in play this round are:
# Two of Clubs
# Four of Diamonds
# Jack of Diamonds
# [2]
# Xhoni is the winner of this round!
#
# Round 19:
# Andi has 6 cards on his deck.
# Ildi has 8 cards on his deck.
# Xhoni has 35 cards on his deck.
# Cards in play this round are:
# Six of Clubs
# Eight of Hearts
# Queen of Clubs
# [2]
# Xhoni is the winner of this round!
#
# Round 20:
# Andi has 5 cards on his deck.
# Ildi has 7 cards on his deck.
# Xhoni has 37 cards on his deck.
# Cards in play this round are:
# Eight of Clubs
# Eight of Spades
# Five of Clubs
# [0, 1]
# Ildi is the winner of this round!
#
# Round 21:
# Andi has 0 cards on his deck.
# Ildi has 13 cards on his deck.
# Xhoni has 36 cards on his deck.
# Andi is out of the game!
# Cards in play this round are:
# King of Clubs
# Jack of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 22:
# Ildi has 14 cards on his deck.
# Xhoni has 35 cards on his deck.
# Cards in play this round are:
# Nine of Hearts
# Ten of Spades
# [1]
# Xhoni is the winner of this round!
#
# Round 23:
# Ildi has 13 cards on his deck.
# Xhoni has 36 cards on his deck.
# Cards in play this round are:
# King of Spades
# Three of Clubs
# [0]
# Ildi is the winner of this round!
#
# Round 24:
# Ildi has 14 cards on his deck.
# Xhoni has 35 cards on his deck.
# Cards in play this round are:
# Queen of Hearts
# Jack of Clubs
# [0]
# Ildi is the winner of this round!
#
# Round 25:
# Ildi has 15 cards on his deck.
# Xhoni has 34 cards on his deck.
# Cards in play this round are:
# Seven of Diamonds
# Two of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 26:
# Ildi has 16 cards on his deck.
# Xhoni has 33 cards on his deck.
# Cards in play this round are:
# Ace of Spades
# Seven of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 27:
# Ildi has 17 cards on his deck.
# Xhoni has 32 cards on his deck.
# Cards in play this round are:
# Ten of Clubs
# Ten of Hearts
# [0, 1]
# Xhoni is the winner of this round!
#
# Round 28:
# Ildi has 12 cards on his deck.
# Xhoni has 37 cards on his deck.
# Cards in play this round are:
# Eight of Spades
# Nine of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 29:
# Ildi has 11 cards on his deck.
# Xhoni has 38 cards on his deck.
# Cards in play this round are:
# Eight of Clubs
# Six of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 30:
# Ildi has 12 cards on his deck.
# Xhoni has 37 cards on his deck.
# Cards in play this round are:
# Jack of Spades
# Eight of Diamonds
# [0]
# Ildi is the winner of this round!
#
# Round 31:
# Ildi has 13 cards on his deck.
# Xhoni has 36 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Three of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 32:
# Ildi has 14 cards on his deck.
# Xhoni has 35 cards on his deck.
# Cards in play this round are:
# Three of Clubs
# Three of Diamonds
# [0, 1]
# Xhoni is the winner of this round!
#
# Round 33:
# Ildi has 9 cards on his deck.
# Xhoni has 40 cards on his deck.
# Cards in play this round are:
# Seven of Diamonds
# Ace of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 34:
# Ildi has 8 cards on his deck.
# Xhoni has 41 cards on his deck.
# Cards in play this round are:
# Seven of Hearts
# Two of Diamonds
# [0]
# Ildi is the winner of this round!
#
# Round 35:
# Ildi has 9 cards on his deck.
# Xhoni has 40 cards on his deck.
# Cards in play this round are:
# Ace of Spades
# Four of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 36:
# Ildi has 10 cards on his deck.
# Xhoni has 39 cards on his deck.
# Cards in play this round are:
# Six of Hearts
# Queen of Spades
# [1]
# Xhoni is the winner of this round!
#
# Round 37:
# Ildi has 9 cards on his deck.
# Xhoni has 40 cards on his deck.
# Cards in play this round are:
# Eight of Clubs
# King of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 38:
# Ildi has 8 cards on his deck.
# Xhoni has 41 cards on his deck.
# Cards in play this round are:
# Eight of Diamonds
# Queen of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 39:
# Ildi has 7 cards on his deck.
# Xhoni has 42 cards on his deck.
# Cards in play this round are:
# Jack of Spades
# Three of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 40:
# Ildi has 8 cards on his deck.
# Xhoni has 41 cards on his deck.
# Cards in play this round are:
# Three of Hearts
# King of Hearts
# [1]
# Xhoni is the winner of this round!
#
# Round 41:
# Ildi has 7 cards on his deck.
# Xhoni has 42 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Five of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 42:
# Ildi has 8 cards on his deck.
# Xhoni has 41 cards on his deck.
# Cards in play this round are:
# Two of Diamonds
# Seven of Clubs
# [1]
# Xhoni is the winner of this round!
#
# Round 43:
# Ildi has 7 cards on his deck.
# Xhoni has 42 cards on his deck.
# Cards in play this round are:
# Seven of Hearts
# Jack of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 44:
# Ildi has 6 cards on his deck.
# Xhoni has 43 cards on his deck.
# Cards in play this round are:
# Four of Hearts
# Four of Diamonds
# [0, 1]
# Xhoni is the winner of this round!
#
# Round 45:
# Ildi has 1 cards on his deck.
# Xhoni has 48 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Ten of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 46:
# Ildi has 2 cards on his deck.
# Xhoni has 47 cards on his deck.
# Cards in play this round are:
# Ten of Spades
# Nine of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 47:
# Ildi has 3 cards on his deck.
# Xhoni has 46 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Nine of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 48:
# Ildi has 4 cards on his deck.
# Xhoni has 45 cards on his deck.
# Cards in play this round are:
# Nine of Hearts
# Five of Clubs
# [0]
# Ildi is the winner of this round!
#
# Round 49:
# Ildi has 5 cards on his deck.
# Xhoni has 44 cards on his deck.
# Cards in play this round are:
# Ten of Spades
# Seven of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 50:
# Ildi has 6 cards on his deck.
# Xhoni has 43 cards on his deck.
# Cards in play this round are:
# Nine of Spades
# Ace of Clubs
# [1]
# Xhoni is the winner of this round!
#
# Round 51:
# Ildi has 5 cards on his deck.
# Xhoni has 44 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Six of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 52:
# Ildi has 6 cards on his deck.
# Xhoni has 43 cards on his deck.
# Cards in play this round are:
# Five of Clubs
# Five of Diamonds
# [0, 1]
# Xhoni is the winner of this round!
#
# Round 53:
# Ildi has 1 cards on his deck.
# Xhoni has 48 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Nine of Diamonds
# [0]
# Ildi is the winner of this round!
#
# Round 54:
# Ildi has 2 cards on his deck.
# Xhoni has 47 cards on his deck.
# Cards in play this round are:
# Nine of Diamonds
# Eight of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 55:
# Ildi has 3 cards on his deck.
# Xhoni has 46 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Five of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 56:
# Ildi has 4 cards on his deck.
# Xhoni has 45 cards on his deck.
# Cards in play this round are:
# Eight of Spades
# Two of Spades
# [0]
# Ildi is the winner of this round!
#
# Round 57:
# Ildi has 5 cards on his deck.
# Xhoni has 44 cards on his deck.
# Cards in play this round are:
# Nine of Diamonds
# Two of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 58:
# Ildi has 6 cards on his deck.
# Xhoni has 43 cards on his deck.
# Cards in play this round are:
# Five of Hearts
# Ten of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 59:
# Ildi has 5 cards on his deck.
# Xhoni has 44 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Jack of Hearts
# [0]
# Ildi is the winner of this round!
#
# Round 60:
# Ildi has 6 cards on his deck.
# Xhoni has 43 cards on his deck.
# Cards in play this round are:
# Two of Spades
# Queen of Hearts
# [1]
# Xhoni is the winner of this round!
#
# Round 61:
# Ildi has 5 cards on his deck.
# Xhoni has 44 cards on his deck.
# Cards in play this round are:
# Eight of Spades
# Jack of Clubs
# [1]
# Xhoni is the winner of this round!
#
# Round 62:
# Ildi has 4 cards on his deck.
# Xhoni has 45 cards on his deck.
# Cards in play this round are:
# Two of Hearts
# King of Spades
# [1]
# Xhoni is the winner of this round!
#
# Round 63:
# Ildi has 3 cards on his deck.
# Xhoni has 46 cards on his deck.
# Cards in play this round are:
# Nine of Diamonds
# Three of Diamonds
# [0]
# Ildi is the winner of this round!
#
# Round 64:
# Ildi has 4 cards on his deck.
# Xhoni has 45 cards on his deck.
# Cards in play this round are:
# Jack of Hearts
# Three of Clubs
# [0]
# Ildi is the winner of this round!
#
# Round 65:
# Ildi has 5 cards on his deck.
# Xhoni has 44 cards on his deck.
# Cards in play this round are:
# King of Clubs
# Ace of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 66:
# Ildi has 4 cards on his deck.
# Xhoni has 45 cards on his deck.
# Cards in play this round are:
# Three of Diamonds
# Seven of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 67:
# Ildi has 3 cards on his deck.
# Xhoni has 46 cards on his deck.
# Cards in play this round are:
# Nine of Diamonds
# Queen of Spades
# [1]
# Xhoni is the winner of this round!
#
# Round 68:
# Ildi has 2 cards on his deck.
# Xhoni has 47 cards on his deck.
# Cards in play this round are:
# Three of Clubs
# Six of Hearts
# [1]
# Xhoni is the winner of this round!
#
# Round 69:
# Ildi has 1 cards on his deck.
# Xhoni has 48 cards on his deck.
# Cards in play this round are:
# Jack of Hearts
# King of Diamonds
# [1]
# Xhoni is the winner of this round!
#
# Round 70:
# Ildi has 0 cards on his deck.
# Xhoni has 49 cards on his deck.
# Ildi is out of the game!
# Game Over!
# Xhoni is the winner!
